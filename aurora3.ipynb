# %% [markdown]
# ## Aurora3
# - 한국어 문장 감성분석

# %%
import pandas as pd
import re
import konlpy
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np
from tqdm import tqdm
import urllib.request

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x26775082808>)

# %%
train_data = pd.read_table('ratings_train.txt')
df = train_data.iloc[:500,:]
df
# Out:
#            id                                           document  label
# 0     9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1     3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2    10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3     9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4     6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ..        ...                                                ...    ...
# 495  10049872  그냥 기독교영화네요. 좀 더 깊이있는 내용을 기대했는데.. 실망입니다. 영화도 뭔가...      0
# 496   9427493  그냥 책으로 읽는게 더 절절하게 다가온다. 영화는 내용을 너무 비약하고 삭제해서 행...      0
# 497   6629097                                        너무나 감동적인 영화      1
# 498   9995177                              스킨헤드성님들이 이 영화를 싫어합니다.      0
# 499   9600841                    자동차 매니아인 나의 평점은 5점 이하~속았다...아오~      0
#
# [500 rows x 3 columns]

# %%
sent_dic = pd.read_csv('SentiWord_Dict.txt',sep = '\t',header=None)

# %%
sent_dic.iloc[14850,0]='갈등'

# %%
pos_dic = sent_dic[sent_dic[1]>0]
neg_dic = sent_dic[sent_dic[1]<0]
neu_dic = sent_dic[sent_dic[1]==0]

# %%
#텍스트 전처리
def text_preprocess(x):
    text=[]
    a = re.sub('[^가-힣0-9a-zA-Z\\s]', '',x)
    for j in a.split():
        text.append(j)
    return ' '.join(text)

# %%
df['comment'] = df['document'].apply(lambda x : text_preprocess(x))
df
# Out:
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            id                                           document  label  \
# 0     9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1     3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2    10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3     9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4     6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ..        ...                                                ...    ...
# 495  10049872  그냥 기독교영화네요. 좀 더 깊이있는 내용을 기대했는데.. 실망입니다. 영화도 뭔가...      0
# 496   9427493  그냥 책으로 읽는게 더 절절하게 다가온다. 영화는 내용을 너무 비약하고 삭제해서 행...      0
# 497   6629097                                        너무나 감동적인 영화      1
# 498   9995177                              스킨헤드성님들이 이 영화를 싫어합니다.      0
# 499   9600841                    자동차 매니아인 나의 평점은 5점 이하~속았다...아오~      0
#
#                                                comment
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# ..                                                 ...
# 495    그냥 기독교영화네요 좀 더 깊이있는 내용을 기대했는데 실망입니다 영화도 뭔가 엉성해요
# 496  그냥 책으로 읽는게 더 절절하게 다가온다 영화는 내용을 너무 비약하고 삭제해서 행간...
# 497                                        너무나 감동적인 영화
# 498                               스킨헤드성님들이 이 영화를 싫어합니다
# 499                         자동차 매니아인 나의 평점은 5점 이하속았다아오
#
# [500 rows x 4 columns]

# %%
okt = konlpy.tag.Okt()
def tokenize(x):
    text = []
    tokens = okt.pos(x)
    for token in tokens :
        if token[1] == 'Adjective' or token[1]=='Adverb' or token[1] == 'Determiner' or token[1] == 'Noun' or token[1] == 'Verb' or 'Unknown':
            text.append(token[0])
    return text

# %%
tqdm.pandas()
df['comment'] = df['comment'].progress_apply(lambda x: tokenize(x))
df
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 500/500 [00:03<00:00, 159.47it/s]
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            id                                           document  label  \
# 0     9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1     3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2    10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3     9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4     6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ..        ...                                                ...    ...
# 495  10049872  그냥 기독교영화네요. 좀 더 깊이있는 내용을 기대했는데.. 실망입니다. 영화도 뭔가...      0
# 496   9427493  그냥 책으로 읽는게 더 절절하게 다가온다. 영화는 내용을 너무 비약하고 삭제해서 행...      0
# 497   6629097                                        너무나 감동적인 영화      1
# 498   9995177                              스킨헤드성님들이 이 영화를 싫어합니다.      0
# 499   9600841                    자동차 매니아인 나의 평점은 5점 이하~속았다...아오~      0
#
#                                                comment
# 0                              [아, 더빙, 진짜, 짜증나네요, 목소리]
# 1        [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 조차, 가볍지, 않구나]
# 2                  [너, 무재, 밓었, 다그, 래서, 보는것을, 추천, 한, 다]
# 3               [교도소, 이야기, 구먼, 솔직히, 재미, 는, 없다, 평점, 조정]
# 4    [사이, 몬페, 그, 의, 익살스런, 연기, 가, 돋보였던, 영화, 스파이더맨, 에...
# ..                                                 ...
# 495  [그냥, 기독교, 영화, 네, 요, 좀, 더, 깊이, 있는, 내용, 을, 기대했는데...
# 496  [그냥, 책, 으로, 읽는게, 더, 절절, 하게, 다가온다, 영화, 는, 내용, 을...
# 497                                [너무나, 감동, 적, 인, 영화]
# 498                  [스킨헤드, 성, 님, 들이, 이, 영화, 를, 싫어합니다]
# 499  [자동차, 매니아, 인, 나, 의, 평점, 은, 5, 점, 이하, 속, 았, 다, 아오]
#
# [500 rows x 4 columns]

# %%
def make_sent_dict(x) :
    pos=[]
    neg=[]
    tmp={}
    
    for sentence in tqdm(x):
        for word in sentence :
            if len(sent_dic[sent_dic[0]==word])==1: # 기존에 있는 단어라면 그대로 사용
                score = float(sent_dic[sent_dic[0]==word][1])
                if score > 0:
                    pos.append(word)
                elif score < 0:
                    neg.append(word)                
            tmp[word] = {'W':0,'WP':0,'WN':0} # 감성사전 구성
    pos = list(set(pos))
    neg = list(set(neg))
    
    for sentence in tqdm(x):
        for word in sentence :
            tmp[word]['W'] += 20 # 빈도 수
            for po in pos :
                if po in sentence:
                    tmp[word]['WP'] += 20 # 긍정단어과 같은 문장 내 단어일 때
                    break
            for ne in neg:
                if ne in sentence:
                    tmp[word]['WN'] += 20 # 부정단어와 같은 문장내 단어일 때
                    break
    return pos, neg, pd.DataFrame(tmp)

# %%
pos, neg, new_dict = make_sent_dict(df['comment'].values)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:14<00:00, 34.38it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1240.61it/s]

# %%
new_dict
# Out:
#       아  더빙   진짜  짜증나네요  목소리   흠  포스터   보고  초딩    영화  ...  찼었던  반대  성하다  스킨헤드  \
# W   380  40  540     20   40  40   60  480  60  3600  ...   20  20   20    20
# WP  140  20  200      0   20   0   20  140  20  1620  ...   20  20   20     0
# WN  100   0  200      0    0   0    0  160  20   940  ...    0   0    0     0
#
#     들이  싫어합니다  자동차  매니아  이하   았
# W   20     20   20   20  20  20
# WP   0      0    0    0   0   0
# WN   0      0    0    0   0   0
#
# [3 rows x 2834 columns]

# %%
def make_score_dict(d,p,n):
    N=sum(d.iloc[0,::])
    pos_cnt=sum(d.loc[::,p].iloc[0,::])
    neg_cnt=sum(d.loc[::,n].iloc[0,::])
    
    trans =d.T
    trans['neg_cnt']=neg_cnt
    trans['pos_cnt']=pos_cnt
    trans['N']=N

    trans['MI_P']=np.log2(trans['WP']*trans['N']/trans['W']*trans['pos_cnt'])
    trans['MI_N']=np.log2(trans['WN']*trans['N']/trans['W']*trans['neg_cnt'])
    trans['SO_MI']=trans['MI_P'] - trans['MI_N']
    
    trans = trans.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
    trans = trans.sort_values(by=['SO_MI'],ascending=False)
    return trans

# %%
t_dict = make_score_dict(new_dict,pos,neg)
t_dict
# Out:
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#         W   WP   WN  neg_cnt  pos_cnt       N       MI_P       MI_N     SO_MI
# 최고    420  420   20     3460     4080  131320  28.997081  24.366966  4.630115
# 더     380  200   20     3460     4080  131320  28.071081  24.511356  3.559725
# 소재    140  120   20     3460     4080  131320  28.774688  25.951929  2.822760
# 님     140  100   20     3460     4080  131320  28.511654  25.951929  2.559725
# 제일    100  100   20     3460     4080  131320  28.997081  26.437355  2.559725
# ...   ...  ...  ...      ...      ...     ...        ...        ...       ...
# 지루하고   80   20   80     3460     4080  131320  26.997081  28.759283 -1.762203
# 건     140   20   80     3460     4080  131320  26.189726  27.951929 -1.762203
# 뭐     200   20  100     3460     4080  131320  25.675152  27.759283 -2.084131
# 짜증    120   20  120     3460     4080  131320  26.412118  28.759283 -2.347165
# 최악    140   20  140     3460     4080  131320  26.189726  28.759283 -2.569558
#
# [607 rows x 9 columns]

# %%
for i in t_dict.T:
    print(i,round(t_dict.loc[i,'SO_MI'],0))
# Out:
# 최고 5.0
# 더 4.0
# 소재 3.0
# 님 3.0
# 제일 3.0
# 잘 2.0
# 있고 2.0
# 좋은 2.0
# 에선 2.0
# 적 2.0
# 다시 2.0
# 보게 2.0
# 노 2.0
# 감동 2.0
# 사실 2.0
# 당시 2.0
# 대한 2.0
# 멋진 2.0
# 세상 2.0
# 재미있게 2.0
# 또한 2.0
# 표현 2.0
# 없었다 2.0
# 한석규 2.0
# 한번 2.0
# 어떻게 2.0
# 진심 2.0
# 않은 2.0
# 남자 2.0
# 웃음 2.0
# 재미 2.0
# 드라마 2.0
# 없는 2.0
# 입니다 2.0
# 성 2.0
# 연기 1.0
# 그 1.0
# 정말 1.0
# 와 1.0
# 튼 1.0
# 되는 1.0
# 있는데 1.0
# 하 1.0
# 끌 1.0
# 여기 1.0
# 책 1.0
# 저 1.0
# 그러나 1.0
# 까지 1.0
# 어울리고 1.0
# 코미디 1.0
# 도움 1.0
# 가장 1.0
# 봤던 1.0
# 둘 1.0
# 중 1.0
# 고민 1.0
# 지금 1.0
# 겁나 1.0
# 있다 1.0
# 전쟁 1.0
# 보는데 1.0
# 용이 1.0
# 본인 1.0
# 감정 1.0
# 아쉽네요 1.0
# 작품 1.0
# 하게 1.0
# 없어도 1.0
# 에도 1.0
# 보여줬다면 1.0
# 제대로 1.0
# 매력 1.0
# 오늘 1.0
# 근데 1.0
# 자 1.0
# 하나 1.0
# 다른 1.0
# 작가 1.0
# 봤다 1.0
# 는 1.0
# 의 1.0
# 으로 1.0
# 영화 1.0
# 기대 1.0
# 나 1.0
# 너무 1.0
# 조연 1.0
# 했는데 1.0
# 걸 1.0
# 느낌 1.0
# 애 1.0
# 있는 1.0
# 따뜻한 1.0
# 설정 1.0
# 조금 1.0
# 음악 1.0
# 라고 1.0
# 역시 1.0
# 일 1.0
# 된 1.0
# 에서 1.0
# 을 1.0
# 이런 1.0
# 마지막 1.0
# 아 1.0
# 2 1.0
# 네 1.0
# 보다 1.0
# 거 1.0
# 넘 1.0
# 10 1.0
# 이야기 1.0
# 알 1.0
# 가 1.0
# 완전 1.0
# 때 1.0
# 줄 1.0
# 인 1.0
# 안 1.0
# 내 1.0
# 이 1.0
# 로 1.0
# 좀 0.0
# 시간 0.0
# 하는 0.0
# 하고 0.0
# 를 0.0
# 에 0.0
# 도 0.0
# 한 0.0
# 같아서 0.0
# 어릴 0.0
# 댓글 0.0
# 외국 0.0
# 봤지만 0.0
# 쯤 0.0
# 재밋 0.0
# 종방 0.0
# 자극 0.0
# 찬다이게 0.0
# 버킷리스트 0.0
# 같다 0.0
# 가보기엔 0.0
# 나오네요 0.0
# 따라가는 0.0
# 세계 0.0
# 재방송 0.0
# 밖에 0.0
# 보긴 0.0
# 혹 0.0
# 완존 0.0
# 시나 0.0
# 봐줘도 0.0
# 답 0.0
# 죽기 0.0
# 만큼도 0.0
# 발톱 0.0
# 란 0.0
# 남는 0.0
# 살자 0.0
# 들어주기 0.0
# 소원 0.0
# 직전 0.0
# 짜 0.0
# MBC 0.0
# 보지 0.0
# 였던듯 0.0
# 없이 0.0
# 좋았음 0.0
# 지쳐있었는데 0.0
# 이영화 0.0
# 수백향 0.0
# 지옥 0.0
# 금물 0.0
# 짓은 0.0
# 바른 0.0
# 나쁜 0.0
# 하진 0.0
# 판타지영화 0.0
# 그리 0.0
# 무섭고 0.0
# 어린시절 0.0
# 심하게 0.0
# 화이팅 0.0
# 어 0.0
# 어이없지도 0.0
# 류 0.0
# 이고 0.0
# 막장 0.0
# 요즘 0.0
# 등 0.0
# 되어 0.0
# 아쉬워요 0.0
# 않았고요 0.0
# 방도 0.0
# 방송 0.0
# 대본 0.0
# 봐라 0.0
# 얼마나 0.0
# 왠지 0.0
# 있다는 0.0
# 받았고요 0.0
# 배두나 0.0
# 깊어요 0.0
# 이인상 0.0
# 여정 0.0
# 화려한 0.0
# 랑 0.0
# 히 0.0
# 이든 0.0
# 완성 0.0
# 굳이 0.0
# 겁니다 0.0
# 한다 0.0
# 며 0.0
# 밟아까 0.0
# 인형 0.0
# 사슴 0.0
# 미묘한 0.0
# 가족사진 0.0
# 인척 0.0
# 유태인 0.0
# 토마스 0.0
# 동행 0.0
# 필요하니 0.0
# 유대인 0.0
# 권 0.0
# 압 0.0
# 그린 0.0
# 아픔 0.0
# 이후 0.0
# 엇음 0.0
# 느낄수 0.0
# 부정 0.0
# 훈훈하고 0.0
# 선사 0.0
# 앤드류 0.0
# 죽는 0.0
# 하면서 0.0
# 가지 0.0
# 인간 0.0
# 점차 0.0
# 로봇 0.0
# 대변 0.0
# 므 0.0
# 같은데 0.0
# 찐 0.0
# 종영 0.0
# 조 0.0
# 성격 0.0
# 무 0.0
# 가본것 0.0
# 웬만하면 0.0
# 보겠는데 0.0
# 어울리면 0.0
# 남녀 0.0
# 같기도 0.0
# 울먹인거 0.0
# 초가 0.0
# 몬 0.0
# 슬픔이었을까 0.0
# 미안함 0.0
# 그리움 0.0
# 선생님 0.0
# 단어 0.0
# 갑자기 0.0
# 몬초 0.0
# 지르던 0.0
# 빨갱이 0.0
# 슬펐다 0.0
# 먹은 0.0
# 교양 0.0
# 센세이션 0.0
# 놀라게 0.0
# 깜짝 0.0
# 난감하다 0.0
# 비록 0.0
# 중국 0.0
# 싶을 0.0
# 높다 0.0
# 해보였음 0.0
# 어색 0.0
# 없애고 0.0
# 됐다고 0.0
# 하지만 0.0
# 그건 0.0
# 다투는 0.0
# 순이 0.0
# 복 0.0
# 여자애 0.0
# 함 0.0
# 레알 0.0
# 해서 0.0
# 재미없다고 0.0
# 매미 0.0
# 값 0.0
# 필름 0.0
# 묻고싶습니다 0.0
# 할수있을까 0.0
# 받았다고 0.0
# 되도 0.0
# 피해자 0.0
# 받은 0.0
# 되나 0.0
# 부 0.0
# 살해 0.0
# 토막 0.0
# 모녀 0.0
# 작 0.0
# 개연 0.0
# 재미있지 0.0
# 죽는거야 0.0
# 않았다 0.0
# 법 0.0
# 불쾌한 0.0
# 다르게 0.0
# 와는 0.0
# 의도 0.0
# 있지만 0.0
# 조폭 0.0
# 든 0.0
# 멋졌다 0.0
# 재밌다 0.0
# 유쾌하고 0.0
# 새롭웠 0.0
# 들의 0.0
# 재치 0.0
# 해석 0.0
# 재밌을 0.0
# 토록 0.0
# 나오는 0.0
# 실망했음 0.0
# 런가 0.0
# 애니스톤 0.0
# 잇의 0.0
# 위드 0.0
# 저스트 0.0
# 여배우 0.0
# 중요한데 0.0
# 뒷받침 0.0
# 많음 0.0
# 쓸데없이 0.0
# 아깝지 0.0
# 뭥미 0.0
# 아쉽긴 0.0
# 했으면 0.0
# 윤제문 0.0
# 이렇게 0.0
# 명 0.0
# 연출 0.0
# 수작 0.0
# 는데 0.0
# 할랫 0.0
# 경 0.0
# 이라도 0.0
# 풍경 0.0
# 핀란드 0.0
# 나오고 0.0
# 게 0.0
# 보는 0.0
# 베트 0.0
# 남바 0.0
# 차이 0.0
# 만찬 0.0
# 바베트 0.0
# 배우 0.0
# 발견 0.0
# 됐어요 0.0
# 이나 0.0
# 모습 0.0
# 극적 0.0
# 악역 0.0
# 든다 0.0
# 자체 0.0
# 가슴 0.0
# 말 0.0
# 소설 0.0
# 큰 0.0
# 소소한 0.0
# 줄게요 0.0
# 싶어 0.0
# 올리고 0.0
# 살짝 0.0
# 주고 0.0
# 머금 0.0
# 미소 0.0
# 탈 0.0
# 인데 0.0
# 음식 0.0
# 보면서 0.0
# 8 0.0
# 로만 0.0
# 문 0.0
# 꽤 0.0
# 액션 0.0
# 보단 0.0
# 몇 0.0
# 연 0.0
# 움 0.0
# 3 0.0
# 존중 0.0
# 막 0.0
# 너무나도 0.0
# 했던 0.0
# 조정 0.0
# 평점 0.0
# 구먼 0.0
# 교도소 0.0
# 초딩 0.0
# 취향 0.0
# 다지 0.0
# 아님 0.0
# 위 0.0
# 놀아나는 0.0
# 선생 0.0
# 학생 0.0
# 뜻 0.0
# 심오한 0.0
# 나름 0.0
# 요 0.0
# 절대 0.0
# 갈수록 0.0
# 내생 0.0
# 뒤 0.0
# 이해 0.0
# 코 0.0
# 참 0.0
# 어거지 0.0
# 스토리 0.0
# 본 0.0
# 극장 0.0
# 위해 0.0
# 싶은데 0.0
# 엉 0.0
# 화해 0.0
# 시작 0.0
# 그리고 0.0
# 같음 0.0
# 욕심 0.0
# 많았던 0.0
# 뻔하지 0.0
# 남발 0.0
# 계 0.0
# 나라 0.0
# 갈등 0.0
# 코드 0.0
# 불법체류자 0.0
# 화 0.0
# 쪽 0.0
# 한국영 0.0
# 만이라도 0.0
# 전혀 0.0
# 봐도 0.0
# 가요 0.0
# 성룡 0.0
# 현 0.0
# 때려 0.0
# 잡는 0.0
# 좋았을텐데 0.0
# 우상화 0.0
# 지만 0.0
# 너무나 0.0
# 재밌게 0.0
# 만든다고 0.0
# 머 0.0
# 인거 0.0
# 두 0.0
# 미 0.0
# 미국 0.0
# 나오는게 0.0
# 매우 0.0
# 흥행 0.0
# 실감 0.0
# 봤어요 0.0
# 이틀 0.0
# 바이러스 0.0
# 떠들 0.0
# 석 0.0
# 일본 0.0
# 20 0.0
# 년전 0.0
# 믿기 0.0
# 힘들 0.0
# 만들었다고 0.0
# 그런 0.0
# 본다 0.0
# 온몸 0.0
# 후반 0.0
# 부가 0.0
# 에볼라 0.0
# 하려고 0.0
# 진짜 0.0
# 은 0.0
# 못 0.0
# 과 0.0
# 보고 0.0
# 점 0.0
# 장면 -0.0
# 전 -0.0
# 면 -0.0
# 볼 -0.0
# 것 -0.0
# 들 -0.0
# 라 -0.0
# 서 -0.0
# 임 -0.0
# 하면 -0.0
# 지 -0.0
# 속 -0.0
# 이건 -0.0
# 이다 -0.0
# 고 -0.0
# 기 -0.0
# 내용 -0.0
# 빨리 -0.0
# 남 -0.0
# 이라는 -0.0
# OO -0.0
# 에게 -0.0
# 에서도 -0.0
# 더럽게 -0.0
# 여 -0.0
# 대 -0.0
# 이라고 -0.0
# 만 -0.0
# 같은 -0.0
# 정도 -1.0
# 없고 -1.0
# 그냥 -1.0
# 별로 -1.0
# 뻔 -1.0
# 어느 -1.0
# 이제 -1.0
# 기억 -1.0
# 영 -1.0
# 더러운 -1.0
# 봐서 -1.0
# 그만 -1.0
# 모든 -1.0
# 소리 -1.0
# 해 -1.0
# 많이 -1.0
# 잔잔한 -1.0
# 참고 -1.0
# 였음 -1.0
# 맨날 -1.0
# 뭔가 -1.0
# 무슨 -1.0
# 충격 -1.0
# 그것 -1.0
# 어떤 -1.0
# 몰입도 -1.0
# 보기 -1.0
# 냐 -1.0
# 합니다 -1.0
# 없음 -1.0
# 나옴 -1.0
# 노력 -1.0
# 듯 -1.0
# 살인자 -1.0
# 살인 -1.0
# 라니 -1.0
# 있어야 -1.0
# 명작 -1.0
# 이지만 -1.0
# 구 -1.0
# 대해 -1.0
# 부터 -1.0
# 개 -1.0
# 잇 -1.0
# 솔직히 -1.0
# 많은 -1.0
# 쓰레기 -1.0
# 이상함 -1.0
# 사람 -1.0
# 생각 -1.0
# 다 -1.0
# 왜 -1.0
# 주인공 -1.0
# 난 -1.0
# 실망 -1.0
# 전개 -1.0
# 없다 -1.0
# 력 -1.0
# 눈 -1.0
# 손 -1.0
# 수준 -1.0
# 엔 -1.0
# 자신 -1.0
# 연기력 -1.0
# 1 -1.0
# 이야 -1.0
# 감독 -1.0
# 재미없다 -1.0
# 노잼 -1.0
# 이네 -1.0
# 추억 -1.0
# 결국 -1.0
# 아깝다 -2.0
# 돈 -2.0
# 인가 -2.0
# 지루하고 -2.0
# 건 -2.0
# 뭐 -2.0
# 짜증 -2.0
# 최악 -3.0

# %%
def update_dict(d):
    add_Dic = {0:[],1:[]}
    for i in d[d['SO_MI']>0].T.keys():
        if i not in list(sent_dic[0]):
            if len(i) > 1:
                add_Dic[0].append(i)
                add_Dic[1].append(1.0)
    for i in d[d['SO_MI']<0].T.keys():
        if i not in list(sent_dic[0]):
            add_Dic[0].append(i)
            add_Dic[1].append(-1.0)
            
    add_Dic=pd.DataFrame(add_Dic)
    Sentiment=pd.merge(sent_dic,add_Dic,'outer')
    return Sentiment

# %%
add_dict =update_dict(t_dict)
add_dict
# Out:
#            0    1
# 0        (-;  1.0
# 1      (;_;) -1.0
# 2       (^^)  1.0
# 3      (^-^)  1.0
# 4       (^^*  1.0
# ...      ...  ...
# 15299     결국 -1.0
# 15300      돈 -1.0
# 15301     인가 -1.0
# 15302      건 -1.0
# 15303      뭐 -1.0
#
# [15304 rows x 2 columns]

# %%
def get_cnt(x):
    cnt = 0
    for word in list(set(x)):
        if len(add_dict[add_dict[0]==word])==1:
            score = float(add_dict[add_dict[0]==word][1])
            print(word,score)
            cnt += score
    return cnt

def get_ratio(x):
    score = x['score']
    length = len(x['comment'])
    ratio= round(score/length,2)
    return ratio

# %%
df['score']= df['comment'].apply(lambda x : get_cnt(x))
# Out:
# 진짜 1.0
# 초딩 1.0
# 보고 1.0
# 영화 1.0
# 연기 1.0
# 다 -1.0
# 없다 -1.0
# 교도소 1.0
# 구먼 1.0
# 재미 2.0
# 조정 1.0
# 이야기 1.0
# 평점 1.0
# 솔직히 -1.0
# 영화 1.0
# 에서 1.0
# 연기 1.0
# 너무나도 1.0
# 했던 1.0
# 1 -1.0
# 부터 -1.0
# 영화 1.0
# 제대로 1.0
# 만 -1.0
# 드라마 1.0
# 그것 -1.0
# 욕 -2.0
# 보단 1.0
# 기 -1.0
# 연기 1.0
# 정말 1.0
# 사람 -1.0
# 하는 1.0
# 아깝다 -1.0
# 없다 -1.0
# 납치 -2.0
# 못 0.0
# 있는 1.0
# 액션 1.0
# 재미 2.0
# 영화 1.0
# 볼 -1.0
# 만 -1.0
# 너무 1.0
# 평점 1.0
# 이다 -1.0
# 진짜 1.0
# 이다 -1.0
# 뻔 -1.0
# 고 -1.0
# 연기 1.0
# 서 -1.0
# 들 -1.0
# 못 0.0
# 손 -1.0
# 해 -2.0
# 보다 1.0
# 로만 1.0
# 기 -1.0
# 사람 -1.0
# 들 -1.0
# 좋다 2.0
# 것 -1.0
# 만 -1.0
# 다지 1.0
# 영화 1.0
# 고 -1.0
# 스토리 1.0
# 임 -1.0
# 에서 1.0
# 존중 1.0
# 취향 1.0
# 진짜 1.0
# 어거지 1.0
# 노잼 -1.0
# 가장 1.0
# 내생 1.0
# 극장 1.0
# 감동 2.0
# 이라고 -1.0
# 라고 1.0
# 들 -1.0
# 사람 -1.0
# 면 -1.0
# 안달 -1.0
# 난 -1.0
# 것 -1.0
# 것 -1.0
# 왜 -1.0
# 갈수록 1.0
# 재미 2.0
# 이해 1.0
# 잘 1.0
# 이건 -1.0
# 지 -1.0
# 않은 1.0
# 정말 1.0
# 산뜻한 1.0
# 절대 1.0
# 들 -1.0
# 착한 2.0
# 나름 1.0
# 있는 1.0
# 학생 1.0
# 아님 1.0
# 심오한 1.0
# 선생 1.0
# 절대 1.0
# 듯 -1.0
# 그냥 -1.0
# 영화 1.0
# 놀아나는 -1.0
# 건 -1.0
# 보면서 1.0
# 할랫 1.0
# 남바 1.0
# 영화 1.0
# 지루하고 -1.0
# 볼 -1.0
# 나옴 -1.0
# 하고 1.0
# 만찬 1.0
# 그것 -1.0
# 재미 2.0
# 이건 -1.0
# 인데 1.0
# 나오고 1.0
# 음식 1.0
# 별로 -1.0
# 풍경 1.0
# 이라도 1.0
# 핀란드 1.0
# 바베트 1.0
# 차이 1.0
# 없다 -1.0
# 베트 1.0
# 있고 1.0
# 재미없다 -1.0
# 는데 1.0
# 있는데 1.0
# 이야기 1.0
# 보는 1.0
# 같은 -1.0
# 구 -1.0
# 수작 1.0
# 절대 1.0
# 영화 1.0
# 지루하다 -1.0
# 부터 -1.0
# 다 -1.0
# 발연기 -1.0
# 있는 1.0
# 력 -1.0
# 연출 1.0
# 탁월한 1.0
# 완전 1.0
# 드라마 1.0
# 깨닫게 1.0
# 연기 1.0
# 정말 1.0
# 다시 1.0
# 한번 1.0
# 쓰레기 -1.0
# 왜 -1.0
# 1 -1.0
# 입니다 1.0
# 드라마 1.0
# 최고 2.0
# 대한 1.0
# 열정 1.0
# 연기 1.0
# 작가 1.0
# 이네 -1.0
# 왜 -1.0
# 영화 1.0
# 이렇게 1.0
# 영화 1.0
# 매력 1.0
# 완전 1.0
# 영화 1.0
# 다 -1.0
# 싱거운 -1.0
# 없음 -1.0
# 시간 1.0
# 내용 -1.0
# 하나 1.0
# 없고 -1.0
# 인가 -1.0
# 보는 1.0
# 정말 1.0
# 10 1.0
# 조금 1.0
# 싶어 1.0
# 합니다 -1.0
# 주고 1.0
# 탈 -1.0
# 윤제문 1.0
# 소소한 1.0
# 배우 1.0
# 발견 1.0
# 음악 1.0
# 잔잔한 -1.0
# 아쉽네요 1.0
# 평점 1.0
# 줄게요 1.0
# 머금 1.0
# 미소 2.0
# 이라는 -1.0
# 멋진 1.0
# 하게 1.0
# 올리고 1.0
# 됐어요 1.0
# 싶은데 1.0
# 시간 1.0
# 임 -1.0
# 돈 -1.0
# 평점 1.0
# 낭비 -1.0
# 고 -1.0
# 조금 1.0
# 하고 1.0
# 욕 -2.0
# 엔 -1.0
# 사람 -1.0
# 갈수록 1.0
# 였음 -1.0
# 장애 -2.0
# 왜 -1.0
# 수준 -1.0
# 마이너스 -2.0
# 만 -1.0
# 돈 -1.0
# 에서 1.0
# 보고 1.0
# 영화 1.0
# 사랑 2.0
# 영화 1.0
# 난 -1.0
# 합니다 -1.0
# 용이 1.0
# 에선 1.0
# 제일 1.0
# 웃음 1.0
# 하고 1.0
# 드라마 1.0
# 이나 1.0
# 라 -1.0
# 감독 -1.0
# 소설 1.0
# 속 -1.0
# 멋진 1.0
# 영화 1.0
# 사람 -1.0
# 거친 -2.0
# 같은 -1.0
# 드라마 1.0
# 가슴 1.0
# 자체 1.0
# 감동 2.0
# 이렇게 1.0
# OO -1.0
# 그냥 -1.0
# 무슨 -1.0
# 원한 -2.0
# 전 -1.0
# 최고 2.0
# 너무 1.0
# 생각 -1.0
# 충격 -1.0
# 없는 1.0
# 들 -1.0
# 정말 1.0
# 하는 1.0
# 너무나도 1.0
# 무자비하다 -2.0
# 하나 1.0
# 력 -1.0
# 느낌 1.0
# 든다 1.0
# 영화 1.0
# 악역 1.0
# 없는 1.0
# 영화 1.0
# 느낌 1.0
# 속 -1.0
# 조금 1.0
# 빨리 -1.0
# 하고 1.0
# 기 -1.0
# 맨날 -1.0
# 주인공 -1.0
# 극적 1.0
# 전개 -1.0
# 모습 1.0
# 짜증 -2.0
# 감정 1.0
# 사랑 2.0
# 영화 1.0
# 정말 1.0
# 하고 1.0
# 최고 2.0
# 슬픈 -2.0
# 만 -1.0
# 보고 1.0
# 입니다 1.0
# 하고 1.0
# 생각 -1.0
# 합니다 -1.0
# 이건 -1.0
# 대해 -1.0
# 다 -1.0
# 들 -1.0
# 사람 -1.0
# 노력 -1.0
# 살인자 -2.0
# 위해 1.0
# 많은 -1.0
# 했으면 1.0
# 이야 -1.0
# 살인 -1.0
# 고 -1.0
# 작품 1.0
# 나오고 1.0
# 내용 -1.0
# 으로 1.0
# 이제 -1.0
# 몰입도 -1.0
# 에도 1.0
# 연기력 -1.0
# 지루하고 -1.0
# 하고 1.0
# 들 -1.0
# 듯 -1.0
# 영화 1.0
# 이다 -1.0
# 진짜 1.0
# 으로 1.0
# 망신 -2.0
# 이런 1.0
# 유치하다 -1.0
# 다 -1.0
# 일본 1.0
# 영화 1.0
# 하려고 1.0
# 다 -1.0
# 봤어요 1.0
# 하면 -1.0
# 그런 1.0
# 내용 -1.0
# 건 -1.0
# 자체 1.0
# 근데 1.0
# 이틀 1.0
# 어설픈 -1.0
# 전개 -1.0
# 냐 -1.0
# 영화 1.0
# 부패한 -1.0
# 온몸 1.0
# 들 -1.0
# 했던 1.0
# 으로 1.0
# 내용 -1.0
# 전개 -1.0
# 잘 1.0
# 매우 1.0
# 실망 -2.0
# 코드 1.0
# 10 1.0
# 뻔하지 1.0
# 갈등 nan
# 흥행 2.0
# 한국영 1.0
# 속 -1.0
# 화 -2.0
# 감동 2.0
# 뭐 -1.0
# 화해 1.0
# 평점 1.0
# 남발 1.0
# 냐 -1.0
# 시작 1.0
# 뭐 -1.0
# 하고 1.0
# 라고 1.0
# 최고 2.0
# 개 -1.0
# 이다 -1.0
# 에게 -1.0
# 감독 -1.0
# 영화 1.0
# 이건 -1.0
# 뭐 -1.0
# 냐 -1.0
# 쓰레기 -1.0
# 정말 1.0
# 입니다 1.0
# 영화 1.0
# 임 -1.0
# 영화 1.0
# 위대한 2.0
# 최고 2.0
# 기대 1.0
# 되는 1.0
# 근데 1.0
# 가요 1.0
# 진짜 1.0
# 눈 -1.0
# 성룡 1.0
# 듯 -1.0
# 최악 -2.0
# 영화 1.0
# 잘 1.0
# 완전 1.0
# 여 -1.0
# 영화 1.0
# 완전 1.0
# 정말 1.0
# 강추 2.0
# 재미있는 2.0
# 입니다 1.0
# 영화 1.0
# 고 -1.0
# 진짜 1.0
# 보면서 1.0
# 다 -1.0
# 영화 1.0
# 너무 1.0
# 설정 1.0
# 스토리 1.0
# 에서 1.0
# 새로운 1.0
# 나오는게 1.0
# 하나 1.0
# 연기 1.0
# 잘 1.0
# 진심 1.0
# 1 -1.0
# 듯 -1.0
# 못 0.0
# 인거 1.0
# 보다 1.0
# 만 -1.0
# 영화 1.0
# 볼 -1.0
# 생각 -1.0
# 감독 -1.0
# 영화 1.0
# 들 -1.0
# 스토리 1.0
# 속 -1.0
# 영화 1.0
# 했으면 1.0
# 하면 -1.0
# 영화 1.0
# 이네 -1.0
# 행복 2.0
# 재미있게 2.0
# 매력 1.0
# 음악 1.0
# 영화 1.0
# 볼 -1.0
# 냐 -1.0
# 보다 1.0
# 영화 1.0
# 으로 1.0
# 전개 -1.0
# 만 -1.0
# 으로 1.0
# 짜증 -2.0
# 시간 1.0
# 라 -1.0
# 느낌 1.0
# 솔직히 -1.0
# 난 -1.0
# 낭비 -1.0
# 드라마 1.0
# 명작 -1.0
# 서운하다 -2.0
# 되는 1.0
# 다 -1.0
# 들 -1.0
# 내용 -1.0
# 봤다 1.0
# 재밌게 1.0
# 내용 -1.0
# 전개 -1.0
# 너무나 1.0
# 느리다 -1.0
# 전개 -1.0
# 이야기 1.0
# 흥미 1.0
# 소재 1.0
# 지만 1.0
# 쓰레기 -1.0
# 절대 1.0
# 영화 1.0
# 왜 -1.0
# 설정 1.0
# 까지 1.0
# 실감 1.0
# 들 -1.0
# 노력 -1.0
# 것 -1.0
# 쓴 -1.0
# 이렇게 1.0
# 따뜻한 2.0
# 설정 1.0
# 때려 -1.0
# 잡는 1.0
# 무슨 -1.0
# 좋았을텐데 1.0
# 만든다고 1.0
# 면 -1.0
# 이건 -1.0
# 그냥 -1.0
# 미국 1.0
# 영화 1.0
# 뭥미 1.0
# 우상화 1.0
# 불법체류자 1.0
# 듯 -1.0
# 주인공 -1.0
# 10 1.0
# 별로 -1.0
# 다 -1.0
# 왜 -1.0
# 대 -1.0
# 다시 1.0
# 연기 1.0
# 또한 1.0
# 감동 2.0
# 보게 1.0
# 사랑 2.0
# 영화 1.0
# 봐도 1.0
# 순수한 1.0
# 완전 1.0
# 만 -1.0
# 같음 1.0
# 볼 -1.0
# 하고 1.0
# 스토리 1.0
# 임 -1.0
# 이건 -1.0
# 다 -1.0
# 들 -1.0
# 배우 1.0
# 그리고 1.0
# 별로 -1.0
# 진심 1.0
# 전혀 1.0
# 많았던 1.0
# 어느 -1.0
# 보여줬다면 1.0
# 욕심 -1.0
# 만이라도 1.0
# 영화 1.0
# 너무 1.0
# 제대로 1.0
# 이나 1.0
# 도둑 -1.0
# 에서 1.0
# 같은 -1.0
# 영화 1.0
# 나라 1.0
# 들 -1.0
# 하고 1.0
# 용기 1.0
# 온몸 1.0
# 교훈 1.0
# 영 -1.0
# 정말 1.0
# 당시 1.0
# 작품 1.0
# 있고 1.0
# 재밌게 1.0
# 그만 -1.0
# 에서 1.0
# 하나 1.0
# 뭐 -1.0
# 다 -1.0
# 없음 -1.0
# 하는 1.0
# 이제 -1.0
# 어설픈 -1.0
# 한석규 1.0
# 만 -1.0
# 지 -1.0
# 영화 1.0
# 연기 1.0
# 많이 -1.0
# 본다 1.0
# 바이러스 -1.0
# 년전 1.0
# 이라고 -1.0
# 에볼라 1.0
# 보게 1.0
# 후반 1.0
# 서 -1.0
# 영화 1.0
# 성 0.0
# 라고 1.0
# 아쉽긴 1.0
# 살짝 1.0
# 20 1.0
# 마지막 1.0
# 에서도 -1.0
# 엔 -1.0
# 잘 1.0
# 정도 -1.0
# 떠들 1.0
# 정말 1.0
# 아깝지 1.0
# 이나 1.0
# 하지만 1.0
# 작품 1.0
# 믿기 1.0
# 인데 1.0
# 면 -1.0
# 만들었다고 1.0
# 여 -1.0
# 않은 1.0
# 힘들 -2.0
# 솔직히 -1.0
# 해 -2.0
# 시간 1.0
# 부가 1.0
# 수작 1.0
# 어떤 -1.0
# 보기 -1.0
# 볼 -1.0
# 진짜 1.0
# 이다 -1.0
# 고민 1.0
# 영화 1.0
# 되는 1.0
# 섹시하다 2.0
# 그리고 1.0
# 작품 1.0
# 한번 1.0
# 시간 1.0
# 하게 1.0
# 어떻게 1.0
# 이제 -1.0
# 최고 2.0
# 용이 1.0
# 작가 1.0
# 하고 1.0
# 임 -1.0
# 봐줘도 1.0
# 다 -1.0
# 재방송 1.0
# 맨날 -1.0
# 진짜 1.0
# 별로 -1.0
# 그냥 -1.0
# 하면 -1.0
# 없다 -1.0
# 기대 1.0
# 시나 1.0
# 명작 -1.0
# 이런 1.0
# 남는 1.0
# 보고 1.0
# 봐도 1.0
# 영화 1.0
# 만 -1.0
# 영화 1.0
# 조금 1.0
# 손 -1.0
# 자극 1.0
# 듯 -1.0
# 하는 1.0
# 진짜 1.0
# 충분히 1.0
# 라 -1.0
# 지 -1.0
# 아쉽네요 1.0
# 많이 -1.0
# 못 0.0
# 으로 1.0
# 그만 -1.0
# 라 -1.0
# 지겹다 -2.0
# 고 -1.0
# 이제 -1.0
# 연기 1.0
# 역시 1.0
# 나름 1.0
# 작품 1.0
# 입니다 1.0
# 좋은 2.0
# 영화 1.0
# 너무 1.0
# 정말 1.0
# 실망 -2.0
# 왜 -1.0
# 영화 1.0
# 들 -1.0
# 배우 1.0
# 이런 1.0
# 진짜 1.0
# 자신 -1.0
# 어릴 1.0
# 왜 -1.0
# 10 1.0
# 에선 1.0
# 외국 1.0
# 유명한 1.0
# 초월 1.0
# 영화 1.0
# 입니다 1.0
# 만 -1.0
# 영화 1.0
# 재밋 1.0
# 받았고요 1.0
# 였던듯 1.0
# 오늘 1.0
# MBC 1.0
# 종방 1.0
# 드라마 1.0
# 악역 1.0
# 방도 1.0
# 어이없지도 1.0
# 잘 1.0
# 들 -1.0
# 수백향 1.0
# 정말 1.0
# 그리 1.0
# 대본 1.0
# 방송 1.0
# 요즘 1.0
# 완성 1.0
# 봤어요 1.0
# 막장 1.0
# 화이팅 1.0
# 않았고요 1.0
# 해 -2.0
# 되어 1.0
# 아쉬워요 1.0
# 심하게 -2.0
# 바른 2.0
# 있다는 1.0
# 느낌 1.0
# 지쳐있었는데 1.0
# 이다 -1.0
# 제일 1.0
# 웃음 1.0
# 같음 1.0
# 까지 1.0
# 있는 1.0
# 잘 1.0
# 기 -1.0
# 에서 1.0
# 코미디 1.0
# 정도 -1.0
# 연기 1.0
# 정말 1.0
# 사람 -1.0
# 대한 1.0
# 해낼 1.0
# 요즘 1.0
# 왠지 1.0
# 평점 1.0
# 장면 -1.0
# 에게 -1.0
# 임 -1.0
# 같다 1.0
# 다 -1.0
# 영화 1.0
# 존잘 2.0
# 유쾌하게 2.0
# 다 -1.0
# 영화 1.0
# 소재 1.0
# 성 0.0
# 작품 1.0
# 없는 1.0
# 볼 -1.0
# 너무 1.0
# 하지만 1.0
# 별로 -1.0
# 주인공 -1.0
# 건 -1.0
# 재미없다 -1.0
# 이라는 -1.0
# 영화 1.0
# 너무 1.0
# 고 -1.0
# 어울리고 2.0
# 에서 1.0
# 들 -1.0
# 인데 1.0
# 주인공 -1.0
# 진심 1.0
# 뻔 -1.0
# 내용 -1.0
# 못 0.0
# 라 -1.0
# 그것 -1.0
# 왜 -1.0
# 감독 -1.0
# 영화 1.0
# 들 -1.0
# 배우 1.0
# 였음 -1.0
# 최악 -2.0
# 라니 -1.0
# 대 -1.0
# 정말 1.0
# 아름다운 2.0
# 입니다 1.0
# 영화 1.0
# 것 -1.0
# 힘든 -2.0
# 자극 1.0
# 력 -1.0
# 연출 1.0
# 눈 -1.0
# 봐도 1.0
# 잘 1.0
# 발연기 -1.0
# 영화 1.0
# 듯 -1.0
# 남자 1.0
# 정도 -1.0
# 정말 1.0
# 음악 1.0
# 잔잔한 -1.0
# 싫은 -2.0
# 짜증 -2.0
# 느낌 1.0
# 못 0.0
# 정말 1.0
# 감동 2.0
# 최고 2.0
# 보고 1.0
# 너무 1.0
# 얼마나 1.0
# 볼 -1.0
# 욕 -2.0
# 초딩 1.0
# 들 -1.0
# 사람 -1.0
# 하는 1.0
# 화가 -2.0
# 나오네요 1.0
# 보지 1.0
# 그냥 -1.0
# 내용 -1.0
# 것 -1.0
# 밖에 1.0
# 짜증 -2.0
# 아니다 -2.0
# 장면 -1.0
# 에선 1.0
# 피 0.0
# 역시 1.0
# 지루하고 -1.0
# 만 -1.0
# 왜 -1.0
# 부터 -1.0
# 그만 -1.0
# 없다 -1.0
# 전 -1.0
# 작품 1.0
# 것 -1.0
# 보고 1.0
# 영화 1.0
# 최고 2.0
# 나쁜 -2.0
# 무섭고 -2.0
# 어린시절 1.0
# 절대 1.0
# 판타지영화 1.0
# 추억 -1.0
# 재미있게 2.0
# 금물 1.0
# 너무 1.0
# 가요 1.0
# 지옥 -2.0
# 짓은 1.0
# 봤던 1.0
# 하려고 1.0
# 감정 1.0
# 너무 1.0
# 영화 1.0
# 후회 -2.0
# 에게 -1.0
# 절대 1.0
# 난 -1.0
# 이영화 1.0
# 교훈 1.0
# 나오네요 1.0
# 밖에 1.0
# 화려하게 1.0
# 나름 1.0
# 없이 1.0
# 가볍게 -1.0
# 추억 -1.0
# 좋았음 1.0
# 생각 -1.0
# 다시 1.0
# 너무 1.0
# 가요 1.0
# 봤다 1.0
# 1 -1.0
# 사랑스러운 2.0
# 다 -1.0
# 영화 1.0
# 보고 1.0
# 영화 1.0
# 있는 1.0
# 다시 1.0
# 그런 1.0
# 에서 1.0
# 갈수록 1.0
# 이고 1.0
# 요즘 1.0
# 노잼 -1.0
# 웃음 1.0
# 다 -1.0
# 들 -1.0
# 난 -1.0
# 감동 2.0
# 하려고 1.0
# 이든 1.0
# 또한 1.0
# 얼마나 1.0
# 생각 -1.0
# 표현 1.0
# 사랑 2.0
# 다 -1.0
# 하는 1.0
# 노력 -1.0
# 보여줬다면 1.0
# 시간 1.0
# 하게 1.0
# 개 -1.0
# 이다 -1.0
# 시간 1.0
# 일본 1.0
# 다 -1.0
# 영화 1.0
# 들 -1.0
# 하는 1.0
# 그리고 1.0
# 너무 1.0
# 정말 1.0
# 웃는 2.0
# 정말 1.0
# 깊어요 1.0
# 잘 1.0
# 이인상 1.0
# 화려한 1.0
# 연기 1.0
# 배두나 1.0
# 여정 1.0
# 재밋 1.0
# 해 -2.0
# 10 1.0
# 영화 1.0
# 감동 2.0
# 영화 1.0
# 없다 -1.0
# 봐라 1.0
# 이건 -1.0
# 그냥 -1.0
# 멋진 1.0
# 다른 1.0
# 들 -1.0
# 사랑 2.0
# 영화 1.0
# 사람 -1.0
# 정말 1.0
# 없는 1.0
# 역시 1.0
# 최고 2.0
# 너무 1.0
# 욕 -2.0
# 에서 1.0
# 너무 1.0
# 있는데 1.0
# 영화 1.0
# 고 -1.0
# 없다 -1.0
# 영화 1.0
# 역시 1.0
# 평점 1.0
# 작품 1.0
# 가장 1.0
# 연출 1.0
# 영화 1.0
# 성 0.0
# 에도 1.0
# 설레어 1.0
# 드라마 1.0
# 없는 1.0
# 다시 1.0
# 했던 1.0
# 시간 1.0
# 장면 -1.0
# 하나 1.0
# 느낌 1.0
# 진심 1.0
# 재미 2.0
# 너무 1.0
# 평점 1.0
# 하나 1.0
# 재미없다 -1.0
# 지루한 -1.0
# 더럽게 -2.0
# 없는 1.0
# 다 -1.0
# 어떤 -1.0
# 영화 1.0
# 고 -1.0
# 조연 1.0
# 잘 1.0
# 들 -1.0
# 연기 1.0
# 정말 1.0
# 하는 1.0
# 하고 1.0
# 매우 1.0
# 작품 1.0
# 오늘 1.0
# 보게 1.0
# 훌륭한 2.0
# 입니다 1.0
# 하고 1.0
# 영화 1.0
# 다시 1.0
# 않은 1.0
# 느낌 1.0
# 건 -1.0
# 다 -1.0
# 너무 1.0
# 대가 1.0
# 성 0.0
# 영화 1.0
# 연기 1.0
# 당시 1.0
# 이런 1.0
# 한석규 1.0
# 없었다 1.0
# 전 -1.0
# 나라 1.0
# 괴물 -1.0
# 력 -1.0
# 같은 -1.0
# 하면 -1.0
# 만 -1.0
# 버킷리스트 1.0
# 보고 1.0
# 영화 1.0
# 볼 -1.0
# 만큼도 1.0
# 직전 1.0
# 발톱 1.0
# 같아서 1.0
# 기 -1.0
# 같다 1.0
# 실망 -2.0
# 죽기 1.0
# 소원 1.0
# 한번 1.0
# 인거 1.0
# 진짜 1.0
# 하진 1.0
# 찬다이게 1.0
# 따라가는 1.0
# 들어주기 1.0
# 댓글 1.0
# 가보기엔 1.0
# 살자 1.0
# 봤지만 1.0
# 없고 -1.0
# 인가 -1.0
# 완존 1.0
# 쓰레기 -1.0
# 무슨 -1.0
# 못 0.0
# 감동 2.0
# 긍정 1.0
# 만 -1.0
# 보고 1.0
# 하고 1.0
# 드라마 1.0
# 보긴 1.0
# 밝고 2.0
# 연기 1.0
# 들 -1.0
# 인데 1.0
# 시간 1.0
# 보는데 1.0
# 것 -1.0
# 인가 -1.0
# 모순 -1.0
# 이런 1.0
# 어떻게 1.0
# 대단하다 2.0
# 대한 1.0
# 전쟁 1.0
# 잘 1.0
# 하고 1.0
# 10 1.0
# 에선 1.0
# 아님 1.0
# 이건 -1.0
# 일본 1.0
# 에서 1.0
# 으로 1.0
# 배우 1.0
# 기대 1.0
# 역시 1.0
# 세계 1.0
# 이라는 -1.0
# 있다 1.0
# 가치 1.0
# 사랑 2.0
# 느낌 1.0
# 으로 1.0
# 색다른 1.0
# 지 -1.0
# 이해 1.0
# 이영화 1.0
# 미친 -2.0
# 겁니다 1.0
# 화가 -2.0
# 감독 -1.0
# 정도 -1.0
# 없다 -1.0
# 시간 1.0
# 이다 -1.0
# 돈 -1.0
# 생생하게 1.0
# 진짜 1.0
# 싶을 1.0
# 정도 -1.0
# 평점 1.0
# 이상하다 -1.0
# 이다 -1.0
# 진짜 1.0
# 1 -1.0
# 완전 1.0
# 드라마 1.0
# 너무 1.0
# 진짜 1.0
# 너무 1.0
# 연기 1.0
# 이런 1.0
# 잘 1.0
# 영화 1.0
# 부터 -1.0
# 정도 -1.0
# 재미없다 -1.0
# 소설 1.0
# 아니다 -2.0
# 다 -1.0
# 범죄 -2.0
# 영화 1.0
# 없는 1.0
# 뭔가 -1.0
# 영화 1.0
# 매력 1.0
# 되도 1.0
# 되나 1.0
# 라니 -1.0
# 성 0.0
# 묻고싶습니다 1.0
# 들 -1.0
# 사람 -1.0
# 살인자 -2.0
# 할수있을까 1.0
# 살해 -1.0
# 피해자 1.0
# 받은 1.0
# 받았다고 1.0
# 진심 1.0
# 모녀 1.0
# 본인 1.0
# 토막 1.0
# 감동 2.0
# 왜 -1.0
# 평점 1.0
# 이렇게 1.0
# 진짜 1.0
# 명작 -1.0
# 이네 -1.0
# 기 -1.0
# 눈 -1.0
# 아깝다 -1.0
# 없다 -1.0
# 매미 1.0
# OO -1.0
# 것 -1.0
# 수준 -1.0
# 재미 2.0
# 부터 -1.0
# 더럽게 -2.0
# 들 -1.0
# 필름 1.0
# 아깝다 -1.0
# 보고 1.0
# 싶은데 1.0
# 영화 1.0
# 만 -1.0
# 만 -1.0
# 영화 1.0
# 너무 1.0
# 남 -1.0
# 볼 -1.0
# 합니다 -1.0
# 생각 -1.0
# 이네 -1.0
# 정도 -1.0
# 들 -1.0
# 연기력 -1.0
# 주인공 -1.0
# 소리 -1.0
# 자체 1.0
# 안습 -1.0
# 없다 -1.0
# 인데 1.0
# 액션 1.0
# 스토리 1.0
# 완전 1.0
# 영화 1.0
# 좋은 2.0
# 영화 1.0
# 익숙한 1.0
# 모든 -1.0
# 다 -1.0
# 영화 1.0
# 정말 1.0
# 하는 1.0
# 전 -1.0
# 봐서 -1.0
# 기억 -1.0
# 감독 -1.0
# 해 -2.0
# 웃으면서 2.0
# 즐겁게 2.0
# 마지막 1.0
# 잘 1.0
# 연기 1.0
# 전쟁 1.0
# 가슴 1.0
# 보는 1.0
# 으로 1.0
# 됐다고 1.0
# 보다 1.0
# 여자애 1.0
# 해보였음 1.0
# 만 -1.0
# 볼 -1.0
# 생각 -1.0
# 몰입도 -1.0
# 순이 1.0
# 굳이 1.0
# 들 -1.0
# 사람 -1.0
# 없애고 1.0
# 재미없다고 1.0
# 겁나 1.0
# 했는데 1.0
# 해서 1.0
# 다투는 -2.0
# 그건 1.0
# 기대 1.0
# 장면 -1.0
# 레알 1.0
# 근데 1.0
# 어색 1.0
# 없어도 1.0
# 설정 1.0
# 하지만 1.0
# 들 -1.0
# 같은 -1.0
# 뛰어나다 2.0
# 연기 1.0
# 느낌 1.0
# 배우 1.0
# 든다 1.0
# 여 -1.0
# 그냥 -1.0
# 주인공 -1.0
# 1 -1.0
# 수준 -1.0
# 영화 1.0
# 대 -1.0
# 손 -1.0
# 이네 -1.0
# 에서 1.0
# 하는 1.0
# 이런 1.0
# 그냥 -1.0
# 뭐 -1.0
# 지 -1.0
# 전 -1.0
# 어떻게 1.0
# 싸움 -1.0
# 감독 -1.0
# 다 -1.0
# 많이 -1.0
# 보고 1.0
# 이런 1.0
# 하나 1.0
# 만 -1.0
# 모습 1.0
# 이쁜 2.0
# 개연 1.0
# 영화 1.0
# 성 0.0
# 남 -1.0
# 없어도 1.0
# 보고 1.0
# 스토리 1.0
# 돈 -1.0
# 사랑 2.0
# 시간 1.0
# 이야기 1.0
# 엔 -1.0
# 또한 1.0
# 만 -1.0
# 실망했음 1.0
# 영화 1.0
# 너무 1.0
# 고 -1.0
# 보고 1.0
# 위드 1.0
# 조연 1.0
# 봐서 -1.0
# 잇의 1.0
# 들 -1.0
# 쓸데없이 -2.0
# 이런 1.0
# 재미있지 1.0
# 별로 -1.0
# 많음 1.0
# 애니스톤 1.0
# 높다 1.0
# 평점 1.0
# 없음 -1.0
# 여배우 1.0
# 뒷받침 1.0
# 매력 1.0
# 없었다 1.0
# 런가 1.0
# 중요한데 1.0
# 내용 -1.0
# 전 -1.0
# 저스트 1.0
# 자체 1.0
# 않았다 1.0
# 전혀 1.0
# 이틀 1.0
# 드라마 1.0
# 개 -1.0
# 나오는 1.0
# 인가 -1.0
# 왜 -1.0
# 이건 -1.0
# 에서 1.0
# 진짜 1.0
# 모든 -1.0
# 지금 1.0
# 이해 1.0
# 영화 1.0
# 들 -1.0
# 슬픔 -2.0
# 저급 -1.0
# 만 -1.0
# 영화 1.0
# 하고 1.0
# 나오는 1.0
# 개연 1.0
# 연기 1.0
# 외국 1.0
# 장면 -1.0
# 없고 -1.0
# 무슨 -1.0
# 못 0.0
# 영화 1.0
# 정말 1.0
# 재미 2.0
# 즐거움 2.0
# 위해 1.0
# 역시 1.0
# 연기 1.0
# 정말 1.0
# 에도 1.0
# 명작 -1.0
# 일본 1.0
# 영화 1.0
# 그립다 1.0
# 봤던 1.0
# 10 1.0
# 년전 1.0
# 토록 1.0
# 영화 1.0
# 고 -1.0
# 소재 1.0
# 대 -1.0
# 새롭웠 1.0
# 재밌다 1.0
# 들의 1.0
# 해석 1.0
# 있다 1.0
# 유쾌하고 2.0
# 정말 1.0
# 배우 1.0
# 대한 1.0
# 여 -1.0
# 감독 -1.0
# 재밌을 1.0
# 이야 -1.0
# 모습 1.0
# 살인 -1.0
# 재치 1.0
# 본다 1.0
# 그만 -1.0
# 에서 1.0
# 없다 -1.0
# 멋졌다 1.0
# 엔 -1.0
# 정말 1.0
# 이런 1.0
# 어떻게 1.0
# 지금 1.0
# 에서 1.0
# 영화 1.0
# 봐도 1.0
# 최고 2.0
# 지금 1.0
# 돈 -1.0
# 한심하다 -1.0
# 쓰레기 -1.0
# 그러나 1.0
# 좋아 2.0
# 드라마 1.0
# 이다 -1.0
# 많은 -1.0
# 감동 2.0
# 발연기 -1.0
# 로만 1.0
# 영화 1.0
# 같음 1.0
# 들 -1.0
# 사람 -1.0
# 정말 1.0
# 뭐 -1.0
# 주인공 -1.0
# 내용 -1.0
# 없는 1.0
# 안타깝게 -2.0
# 가슴 1.0
# 서 -1.0
# 합니다 -1.0
# 정말 1.0
# 다시 1.0
# 작품 1.0
# 인데 1.0
# 감독 -1.0
# 모든 -1.0
# 봐도 1.0
# 으로 1.0
# 이제 -1.0
# 하게 1.0
# 많은 -1.0
# 독 -2.0
# 하면 -1.0
# 생각 -1.0
# 만 -1.0
# 조폭 1.0
# 영화 1.0
# 하고 1.0
# 라고 1.0
# 갈수록 1.0
# 세상 1.0
# 친구 1.0
# 어릴 1.0
# 멋지다 2.0
# 너무나도 1.0
# 있고 1.0
# 잘 1.0
# 좋고 2.0
# 영화 1.0
# 소재 1.0
# 대 -1.0
# 잘 1.0
# 기 -1.0
# 다 -1.0
# 연기 1.0
# 있지만 1.0
# 못 0.0
# 조폭 1.0
# 있는 1.0
# 지루하다 -1.0
# 남는 1.0
# 코미디 1.0
# 다 -1.0
# 연기 1.0
# 들 -1.0
# 배우 1.0
# 기억 -1.0
# 해 -2.0
# 없다 -1.0
# 건 -1.0
# 하나 1.0
# 이야기 1.0
# 보기 -1.0
# 없이 1.0
# 재미 2.0
# 잘 1.0
# 연기 1.0
# 못 0.0
# 배우 1.0
# 고 -1.0
# 짜증 -2.0
# 못 0.0
# 영화 1.0
# 스토리 1.0
# 최악 -2.0
# 지루하고 -1.0
# 불쾌한 -2.0
# 좋은 2.0
# 다르게 1.0
# 표현 1.0
# 와는 1.0
# 의도 1.0
# 귀여운 2.0
# 보다 1.0
# 당시 1.0
# 명작 -1.0
# 사람 -1.0
# 악역 1.0
# 이다 -1.0
# 이고 1.0
# 감독 -1.0
# 영화 1.0
# 너무 1.0
# 전 -1.0
# 속 -1.0
# 거짓 -2.0
# 영화 1.0
# 지금 1.0
# 에서 1.0
# 못 0.0
# 없다 -1.0
# 여자애 1.0
# 잘 1.0
# 죽는거야 1.0
# 못 0.0
# 해서 1.0
# 성룡 1.0
# 지 -1.0
# 최고 2.0
# 안습 -1.0
# 감독 -1.0
# 전혀 1.0
# 못 0.0
# 의도 1.0
# 봐라 1.0
# 진리 1.0
# 보지 1.0
# 눈 -1.0
# 으로 1.0
# 영화 1.0
# 나름 1.0
# 제일 1.0
# 에서 1.0
# 코미디 1.0
# 영화 1.0
# 좋았음 1.0
# 뭔가 -1.0
# 푸근하고 1.0
# 난 -1.0
# 이다 -1.0
# 뻔 -1.0
# 임 -1.0
# 최악 -2.0
# 영 -1.0
# 하는 1.0
# 들 -1.0
# 배우 1.0
# 몰입도 -1.0
# 이네 -1.0
# 영화 1.0
# 하려고 1.0
# 하고 1.0
# 결국 -1.0
# 듯 -1.0
# 감독 -1.0
# 자신 -1.0
# 이라는 -1.0
# 살인 -1.0
# 보다 1.0
# 중국 1.0
# 너무 1.0
# 고 -1.0
# 하고 1.0
# 그리고 1.0
# 사실 1.0
# 있는데 1.0
# 못 0.0
# 으로 1.0
# 최고 2.0
# 수준 -1.0
# 영화 1.0
# 기대 1.0
# 재미없다 -1.0
# 완전 1.0
# 했는데 1.0
# 못 0.0
# 실망 -2.0
# 없는 1.0
# 시간 1.0
# 돈 -1.0
# 영화 1.0
# 예쁜 2.0
# 영화 1.0
# 잘 1.0
# 없는 1.0
# 하는 1.0
# 음악 1.0
# 하나 1.0
# 것 -1.0
# 연기 1.0
# 들 -1.0
# 배우 1.0
# 왜 -1.0
# 만 -1.0
# 영화 1.0
# 구 -1.0
# 들 -1.0
# 위조 -1.0
# 솔직히 -1.0
# 완전 1.0
# 보기 -1.0
# 들 -1.0
# 하고 1.0
# 나쁘고 -2.0
# 만 -1.0
# 좋은 2.0
# 깔끔한 2.0
# 없는 1.0
# 영화 1.0
# 그러나 1.0
# 그런 1.0
# 그냥 -1.0
# 영화 1.0
# 최고 2.0
# 것 -1.0
# 같은데 1.0
# 빨리 -1.0
# 많이 -1.0
# 감기 -1.0
# 해서 1.0
# 왜 -1.0
# 없는 1.0
# 뭐 -1.0
# 지 -1.0
# 평점 1.0
# 내용 -1.0
# 무슨 -1.0
# 이렇게 1.0
# 왜 -1.0
# 죽임을 -1.0
# 영화 1.0
# 나옴 -1.0
# 있는 1.0
# 마지막 1.0
# 있어야 -1.0
# 다 -1.0
# 하는 1.0
# 그리고 1.0
# 없다 -1.0
# 없고 -1.0
# 이해 1.0
# 개 -1.0
# 절대 1.0
# 다 -1.0
# 영화 1.0
# 보고 1.0
# 쓰레기 -1.0
# 정말 1.0
# 고민 1.0
# 죽는 -1.0
# 영화 1.0
# 고 -1.0
# 인간 1.0
# 앤드류 1.0
# 결국 -1.0
# 에서도 -1.0
# 대해 -1.0
# 가지 1.0
# 로봇 1.0
# 점차 1.0
# 봤던 1.0
# 이지만 -1.0
# 되어 1.0
# 자신 -1.0
# 하면서 1.0
# 선사 1.0
# 감정 1.0
# 모습 1.0
# 비록 1.0
# 감동 2.0
# 최고 2.0
# 다 -1.0
# 영화 1.0
# 왜 -1.0
# 서 -1.0
# 너무 1.0
# 재미 2.0
# 초딩 1.0
# 같다 1.0
# 다시 1.0
# 나름 1.0
# 당시 1.0
# 기억 -1.0
# 없었다 1.0
# 봤던 1.0
# 근데 1.0
# 고요하고 1.0
# 너무 1.0
# 진짜 1.0
# 보고 1.0
# 영화 1.0
# 하면 -1.0
# 같다 1.0
# 아름다운 2.0
# 기 -1.0
# 정말 1.0
# 들 -1.0
# 역시 1.0
# 시간 1.0
# 이야기 1.0
# 개 -1.0
# 진짜 1.0
# 스토리 1.0
# 노잼 -1.0
# 다 -1.0
# 뭔가 -1.0
# 이상함 -1.0
# 뭐 -1.0
# 하는 1.0
# 절망 -2.0
# 자신 -1.0
# 에서도 -1.0
# 속 -1.0
# 여 -1.0
# 슬픔 -2.0
# 같음 1.0
# 시간 1.0
# 있는 1.0
# 영화 1.0
# 진짜 1.0
# 영화 1.0
# 10 1.0
# 절대 1.0
# 다 -1.0
# 않은 1.0
# 주인공 -1.0
# 피 0.0
# 그런 1.0
# 내용 -1.0
# 이야기 1.0
# 같은 -1.0
# 전혀 1.0
# 못 0.0
# 따뜻한 2.0
# 훈훈하고 1.0
# 잇 -1.0
# 느낄수 1.0
# 부정 -1.0
# 엇음 1.0
# 정말 1.0
# 재미있게 2.0
# 전 -1.0
# 영화 1.0
# 볼 -1.0
# 하고 1.0
# 강하다 1.0
# 있는 1.0
# 에서 1.0
# 들 -1.0
# 같은데 1.0
# 이런 1.0
# 했으면 1.0
# 것 -1.0
# 같은 -1.0
# 느낌 1.0
# 10 1.0
# 당시 1.0
# 이고 1.0
# 만 -1.0
# 극장 1.0
# 에서 1.0
# 영화 1.0
# 1 -1.0
# 보고 1.0
# 영화 1.0
# 다 -1.0
# 정말 1.0
# 봐도 1.0
# 느낌 1.0
# 들 -1.0
# 봤어요 1.0
# 여배우 1.0
# 하나 1.0
# 액션 1.0
# 스토리 1.0
# 없는 1.0
# 그냥 -1.0
# 그냥 -1.0
# 다 -1.0
# 도움 1.0
# 영화 1.0
# 고 -1.0
# 입니다 1.0
# 생각 -1.0
# 겁니다 1.0
# 재미 2.0
# 정말 1.0
# 겁나 1.0
# 했는데 1.0
# 가장 1.0
# 본인 1.0
# 있고 1.0
# 액션 1.0
# 최고 2.0
# 영화 1.0
# 영화 1.0
# 소재 1.0
# 하고 1.0
# 있는 1.0
# 보단 1.0
# 남자 1.0
# 들 -1.0
# 아름다운 2.0
# 사실 1.0
# 극적 1.0
# 으로 1.0
# 한번 1.0
# 보고 1.0
# 영화 1.0
# 재밌다 1.0
# 역시 1.0
# 들 -1.0
# 들 -1.0
# 정말 1.0
# 나옴 -1.0
# 슬프다 -2.0
# 이런 1.0
# 에게 -1.0
# 속 -1.0
# 들 -1.0
# 최악 -2.0
# 에서 1.0
# 사람 -1.0
# 남는 1.0
# 사랑 2.0
# 영화 1.0
# 영화 1.0
# 라니 -1.0
# 여 -1.0
# 10 1.0
# 이다 -1.0
# 이든 1.0
# 보다 1.0
# 힘들게 -2.0
# 생각 -1.0
# 결국 -1.0
# 다 -1.0
# 들 -1.0
# 사람 -1.0
# 지만 1.0
# 이런 1.0
# 최악 -2.0
# 왠지 1.0
# 잇 -1.0
# 지 -1.0
# 하면 -1.0
# 별로 -1.0
# 재미없다 -1.0
# 연기 1.0
# 고 -1.0
# 갈팡질팡 -1.0
# 영화 1.0
# 너무 1.0
# 정말 1.0
# 감동 2.0
# 영화 1.0
# 최고 2.0
# 완전 1.0
# 다시 1.0
# 이고 1.0
# 전 -1.0
# 지금 1.0
# 멋지게 2.0
# 못 0.0
# OO -1.0
# 열심히 1.0
# 하면 -1.0
# 그냥 -1.0
# 필요하니 1.0
# 이라고 -1.0
# 인형 1.0
# 도움 1.0
# 영화 1.0
# 여기 1.0
# 그러나 1.0
# 그린 1.0
# 사슴 1.0
# 유태인 1.0
# 전쟁 1.0
# 한다 1.0
# 마지막 1.0
# 잘 1.0
# 아픔 -2.0
# 미묘한 1.0
# 들 -1.0
# 밟아까 1.0
# 대변 1.0
# 보면서 1.0
# 가족사진 1.0
# 더럽게 -2.0
# 동행 1.0
# 했던 1.0
# 토마스 1.0
# 인척 1.0
# 유대인 1.0
# 사실 1.0
# 장면 -1.0
# 에게 -1.0
# 감정 1.0
# 이후 1.0
# 더러운 -2.0
# 이다 -1.0
# 만 -1.0
# 변태 -1.0
# 성공 2.0
# 남자 1.0
# 들 -1.0
# 없다 -1.0
# 내용 -1.0
# 영화 1.0
# 시간 1.0
# 기억 -1.0
# 으로 1.0
# 연기 1.0
# 있고 1.0
# 재미 2.0
# 영화 1.0
# 감동 2.0
# 열정 1.0
# 영화 1.0
# 하고 1.0
# 한다 1.0
# 연기력 -1.0
# 에서 1.0
# 못 0.0
# 없다 -1.0
# 놀라게 1.0
# 세상 1.0
# 재미 2.0
# 깜짝 1.0
# 센세이션 1.0
# 없고 -1.0
# 난감하다 1.0
# 하는 1.0
# 노력 -1.0
# 것 -1.0
# 화이팅 1.0
# 어린시절 1.0
# 만 -1.0
# 느낌 1.0
# 연기 1.0
# 너무 1.0
# 정말 1.0
# 최고 2.0
# 재밌게 1.0
# 영화 1.0
# 보고 1.0
# 너무 1.0
# 영화 1.0
# 하고 1.0
# 충격 -1.0
# 몬초 1.0
# 먹은 1.0
# 빨갱이 1.0
# 단어 1.0
# 마지막 1.0
# 같기도 1.0
# 초가 1.0
# 갑자기 1.0
# 미안함 -1.0
# 슬펐다 1.0
# 대한 1.0
# 라 -1.0
# 다른 1.0
# 그리움 1.0
# 지르던 1.0
# 교양 1.0
# 시간 1.0
# 소리 -1.0
# 건 -1.0
# 선생님 1.0
# 울먹인거 1.0
# 슬픔이었을까 1.0
# 잘 1.0
# 그런 1.0
# 무서워 -2.0
# 건 -1.0
# 이야 -1.0
# 라 -1.0
# 그냥 -1.0
# 지 -1.0
# 깜놀 -1.0
# 것 -1.0
# 모든 -1.0
# 뭐 -1.0
# 다 -1.0
# 어설프고 -1.0
# 따뜻한 2.0
# 실감 1.0
# 다 -1.0
# 연기 1.0
# 들 -1.0
# 배우 1.0
# 정말 1.0
# 봤다 1.0
# 참고 -1.0
# 연기력 -1.0
# 기 -1.0
# 들 -1.0
# 안습 -1.0
# 1 -1.0
# 생각 -1.0
# 전쟁 1.0
# 20 1.0
# 들 -1.0
# 하는 1.0
# 력 -1.0
# 다른 1.0
# 개 -1.0
# 왜 -1.0
# 듯 -1.0
# 싶은데 1.0
# 냐 -1.0
# 장면 -1.0
# 만 -1.0
# 뭐 -1.0
# 다 -1.0
# 정도 -1.0
# 솔직히 -1.0
# 더러운 -2.0
# 작품 1.0
# 연기력 -1.0
# 잘 1.0
# 에서 1.0
# 않은 1.0
# 영화 1.0
# 봐도 1.0
# 보고 1.0
# 있고 1.0
# 만 -1.0
# 없는 1.0
# 피해자 1.0
# 바라는 0.0
# 지 -1.0
# 에서 1.0
# 못 0.0
# 주인공 -1.0
# 액션 1.0
# 전개 -1.0
# 소재 1.0
# 멋졌다 1.0
# 영화 1.0
# 마지막 1.0
# 사랑 2.0
# 남자 1.0
# 정말 1.0
# 하는 1.0
# 대한 1.0
# 한석규 1.0
# 10 1.0
# 충분하다 1.0
# 다 -1.0
# 영화 1.0
# 감동 2.0
# 당시 1.0
# 영화 1.0
# 괜찮다 1.0
# 보다 1.0
# 1 -1.0
# 안타깝다 -2.0
# 억지스러운 -1.0
# 들 -1.0
# 영 -1.0
# 배우 1.0
# 나오는게 1.0
# 지루한 -1.0
# 눈 -1.0
# 없어서 -1.0
# 전개 -1.0
# 못 0.0
# 영화 1.0
# 높은 1.0
# 영화 1.0
# 평점 1.0
# 기억 -1.0
# 정상 1.0
# 영화 1.0
# 소재 1.0
# 요즘 1.0
# 영화 1.0
# 보고 1.0
# 영화 1.0
# 고 -1.0
# 입니다 1.0
# 생각 -1.0
# 마지막 1.0
# 들 -1.0
# 사람 -1.0
# 것 -1.0
# 하게 1.0
# 으로 1.0
# 나오는 1.0
# 진짜 1.0
# 재미 2.0
# 없는 1.0
# 영화 1.0
# 있는 1.0
# 수작 1.0
# 연기 1.0
# 감동 2.0
# 함정 -1.0
# 같다 1.0
# 세계 1.0
# 이지만 -1.0
# 것 -1.0
# 귀여운 2.0
# 똑똑한 2.0
# 친구 1.0
# 예쁘고 2.0
# 당시 1.0
# 돈 -1.0
# 서 -1.0
# 보고 1.0
# 아까워서 -1.0
# 정말 1.0
# 영화 1.0
# 최고 2.0
# 연출 1.0
# 대단하다 2.0
# 영화 1.0
# 까지 1.0
# 표현 1.0
# 싶을 1.0
# 정도 -1.0
# 연기 1.0
# 감정 1.0
# 시간 1.0
# 것 -1.0
# 하나 1.0
# 어느 -1.0
# 연출 1.0
# 중국 1.0
# 연기 1.0
# 못 0.0
# 억지 -1.0
# 으로 1.0
# 하는 1.0
# 작가 1.0
# 빨리 -1.0
# 서 -1.0
# 여기 1.0
# 하고 1.0
# 드라마 1.0
# 그만 -1.0
# 사랑 2.0
# 진짜 1.0
# 면 -1.0
# 하면 -1.0
# 봤다 1.0
# 냐 -1.0
# 내용 -1.0
# 왜 -1.0
# 없고 -1.0
# 높은 1.0
# 영화 1.0
# 영화 1.0
# 진짜 1.0
# 이런 1.0
# 보면서 1.0
# 지금 1.0
# 영화 1.0
# 하면 -1.0
# 하고 1.0
# 잃은 -1.0
# 있지만 1.0
# 추억 -1.0
# 들 -1.0
# 한심한 -1.0
# 다시 1.0
# 눈물 -1.0
# 기억 -1.0
# 어릴 1.0
# 불협화음 -2.0
# 냐 -1.0
# 돈 -1.0
# 없는 1.0
# 영화 1.0
# 연기 1.0
# 같다 1.0
# 주인공 -1.0
# 보긴 1.0
# 영화 1.0
# 너무 1.0
# 아깝다 -1.0
# 마지막 1.0
# 최고 2.0
# 대 -1.0
# 좋아 2.0
# 최고 2.0
# 함부로 -1.0
# 다 -1.0
# 쓰레기 -1.0
# 하나 1.0
# 만 -1.0
# 와는 1.0
# 영화 1.0
# 남녀 1.0
# 이다 -1.0
# 어울리면 1.0
# 제일 1.0
# 부터 -1.0
# 시작 1.0
# 만 -1.0
# 남 -1.0
# 개 -1.0
# 어울리고 2.0
# 재미 2.0
# 있어야 -1.0
# 기 -1.0
# 다 -1.0
# 이상함 -1.0
# 들 -1.0
# 진짜 1.0
# 성격 1.0
# 참고 -1.0
# 웬만하면 1.0
# 보지 1.0
# 최악 -2.0
# 종영 1.0
# 막장 1.0
# 보겠는데 1.0
# 주인공 -1.0
# 였음 -1.0
# 해서 1.0
# 보는데 1.0
# 재밌게 1.0
# 없고 -1.0
# 가본것 1.0
# 짜증 -2.0
# 멋지다 2.0
# 역시 1.0
# 명작 -1.0
# 이다 -1.0
# 잘못 -2.0
# 영화 1.0
# 보고 1.0
# 있는 1.0
# 내용 -1.0
# 입니다 1.0
# 그냥 -1.0
# 뭔가 -1.0
# 영화 1.0
# 실망 -2.0
# 으로 1.0
# 영화 1.0
# 너무 1.0
# 하고 1.0
# 에서 1.0
# 모든 -1.0
# 그냥 -1.0
# 성하다 1.0
# 해서 1.0
# 내용 -1.0
# 것 -1.0
# 하게 1.0
# 느낌 1.0
# 너무나 1.0
# 영화 1.0
# 감동 2.0
# 영화 1.0
# 성 0.0
# 속 -1.0
# 다 -1.0
# 평점 1.0
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['ratio'] = df.apply(lambda x: get_ratio(x), axis = 1)
df
# Out:
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            id                                           document  label  \
# 0     9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1     3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2    10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3     9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4     6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ..        ...                                                ...    ...
# 495  10049872  그냥 기독교영화네요. 좀 더 깊이있는 내용을 기대했는데.. 실망입니다. 영화도 뭔가...      0
# 496   9427493  그냥 책으로 읽는게 더 절절하게 다가온다. 영화는 내용을 너무 비약하고 삭제해서 행...      0
# 497   6629097                                        너무나 감동적인 영화      1
# 498   9995177                              스킨헤드성님들이 이 영화를 싫어합니다.      0
# 499   9600841                    자동차 매니아인 나의 평점은 5점 이하~속았다...아오~      0
#
#                                                comment  score  ratio
# 0                              [아, 더빙, 진짜, 짜증나네요, 목소리]    1.0   0.20
# 1        [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 조차, 가볍지, 않구나]    4.0   0.36
# 2                  [너, 무재, 밓었, 다그, 래서, 보는것을, 추천, 한, 다]   -1.0  -0.11
# 3               [교도소, 이야기, 구먼, 솔직히, 재미, 는, 없다, 평점, 조정]    5.0   0.56
# 4    [사이, 몬페, 그, 의, 익살스런, 연기, 가, 돋보였던, 영화, 스파이더맨, 에...    5.0   0.25
# ..                                                 ...    ...    ...
# 495  [그냥, 기독교, 영화, 네, 요, 좀, 더, 깊이, 있는, 내용, 을, 기대했는데...   -2.0  -0.10
# 496  [그냥, 책, 으로, 읽는게, 더, 절절, 하게, 다가온다, 영화, 는, 내용, 을...    5.0   0.15
# 497                                [너무나, 감동, 적, 인, 영화]    4.0   0.80
# 498                  [스킨헤드, 성, 님, 들이, 이, 영화, 를, 싫어합니다]    1.0   0.12
# 499  [자동차, 매니아, 인, 나, 의, 평점, 은, 5, 점, 이하, 속, 았, 다, 아오]   -1.0  -0.07
#
# [500 rows x 6 columns]
